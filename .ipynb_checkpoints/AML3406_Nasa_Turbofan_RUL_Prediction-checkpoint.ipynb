# %% [markdown]
# ### NASA Turbofan Engine Remaining Useful Life Prediction

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CMAPSSData/train_FD001.txt', delim_whitespace=True, header=None)
df

# %%
# https://data.nasa.gov/Aerospace/CMAPSS-Jet-Engine-Simulated-Data/ff5v-kuh6
# column_names = ['ID', 'Cycle', 'OpSet1', 'OpSet2', 'OpSet3', 'SensorMeasure1', 'SensorMeasure2', 'SensorMeasure3', 'SensorMeasure4', 
#               'SensorMeasure5', 'SensorMeasure6', 'SensorMeasure7', 'SensorMeasure8', 'SensorMeasure9', 'SensorMeasure10', 'SensorMeasure11', 
#               'SensorMeasure12', 'SensorMeasure13', 'SensorMeasure14', 'SensorMeasure15', 'SensorMeasure16', 'SensorMeasure17', 'SensorMeasure18', 
#               'SensorMeasure19', 'SensorMeasure20', 'SensorMeasure21']

# Remaining Useful Life Prediction of a Turbofan Engine Using Deep Layer Recurrent Neural Networks by Unnati Thakkar
column_names = ['EngineNo', 'Cycle', 'OpSet1', 'OpSet2', 'OpSet3', 'FanInletTemp', 'LPCOutletTemp', 'HPCOutletTemp', 'LPTOutletTemp', 'FanInletPressure',
              'ByPassDuctPressure', 'TotalHPCOutletPressure', 'PhysicalFanSpeed', 'PhysicalCoreSpeed',
              'EnginePressureRatio', 'StaticHPCOutletPressure', 'FuelFlowRatio', 'CorctFanSpeed', 'CorctCoreSpeed', 'BPR', 
              'BurnerFuelRatio', 'BleedEnthalpy', 'DemandFanSpeed', 'DemandCorctFanSpeed', 'HPTCoolantBleed', 'LPTCoolantBleed']
df.columns = column_names
df.head()
# Out:
#    EngineNo  Cycle  OpSet1  OpSet2  OpSet3  FanInletTemp  LPCOutletTemp  \
# 0         1      1 -0.0007 -0.0004   100.0        518.67         641.82
# 1         1      2  0.0019 -0.0003   100.0        518.67         642.15
# 2         1      3 -0.0043  0.0003   100.0        518.67         642.35
# 3         1      4  0.0007  0.0000   100.0        518.67         642.35
# 4         1      5 -0.0019 -0.0002   100.0        518.67         642.37
#
#    HPCOutletTemp  LPTOutletTemp  FanInletPressure  ...  FuelFlowRatio  \
# 0        1589.70        1400.60             14.62  ...         521.66
# 1        1591.82        1403.14             14.62  ...         522.28
# 2        1587.99        1404.20             14.62  ...         522.42
# 3        1582.79        1401.87             14.62  ...         522.86
# 4        1582.85        1406.22             14.62  ...         522.19
#
#    CorctFanSpeed  CorctCoreSpeed     BPR  BurnerFuelRatio  BleedEnthalpy  \
# 0        2388.02         8138.62  8.4195             0.03            392
# 1        2388.07         8131.49  8.4318             0.03            392
# 2        2388.03         8133.23  8.4178             0.03            390
# 3        2388.08         8133.83  8.3682             0.03            392
# 4        2388.04         8133.80  8.4294             0.03            393
#
#    DemandFanSpeed  DemandCorctFanSpeed  HPTCoolantBleed  LPTCoolantBleed
# 0            2388                100.0            39.06          23.4190
# 1            2388                100.0            39.00          23.4236
# 2            2388                100.0            38.95          23.3442
# 3            2388                100.0            38.88          23.3739
# 4            2388                100.0            38.90          23.4044
#
# [5 rows x 26 columns]

# %%
df.describe()
# Out:
#            EngineNo         Cycle        OpSet1        OpSet2   OpSet3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.0
# mean      51.506568    108.807862     -0.000009      0.000002    100.0
# std       29.227633     68.880990      0.002187      0.000293      0.0
# min        1.000000      1.000000     -0.008700     -0.000600    100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200    100.0
# 50%       52.000000    104.000000      0.000000      0.000000    100.0
# 75%       77.000000    156.000000      0.001500      0.000300    100.0
# max      100.000000    362.000000      0.008700      0.000600    100.0
#
#        FanInletTemp  LPCOutletTemp  HPCOutletTemp  LPTOutletTemp  \
# count  2.063100e+04   20631.000000   20631.000000   20631.000000
# mean   5.186700e+02     642.680934    1590.523119    1408.933782
# std    6.537152e-11       0.500053       6.131150       9.000605
# min    5.186700e+02     641.210000    1571.040000    1382.250000
# 25%    5.186700e+02     642.325000    1586.260000    1402.360000
# 50%    5.186700e+02     642.640000    1590.100000    1408.040000
# 75%    5.186700e+02     643.000000    1594.380000    1414.555000
# max    5.186700e+02     644.530000    1616.910000    1441.490000
#
#        FanInletPressure  ...  FuelFlowRatio  CorctFanSpeed  CorctCoreSpeed  \
# count      2.063100e+04  ...   20631.000000   20631.000000    20631.000000
# mean       1.462000e+01  ...     521.413470    2388.096152     8143.752722
# std        3.394700e-12  ...       0.737553       0.071919       19.076176
# min        1.462000e+01  ...     518.690000    2387.880000     8099.940000
# 25%        1.462000e+01  ...     520.960000    2388.040000     8133.245000
# 50%        1.462000e+01  ...     521.480000    2388.090000     8140.540000
# 75%        1.462000e+01  ...     521.950000    2388.140000     8148.310000
# max        1.462000e+01  ...     523.380000    2388.560000     8293.720000
#
#                 BPR  BurnerFuelRatio  BleedEnthalpy  DemandFanSpeed  \
# count  20631.000000     2.063100e+04   20631.000000         20631.0
# mean       8.442146     3.000000e-02     393.210654          2388.0
# std        0.037505     1.556432e-14       1.548763             0.0
# min        8.324900     3.000000e-02     388.000000          2388.0
# 25%        8.414900     3.000000e-02     392.000000          2388.0
# 50%        8.438900     3.000000e-02     393.000000          2388.0
# 75%        8.465600     3.000000e-02     394.000000          2388.0
# max        8.584800     3.000000e-02     400.000000          2388.0
#
#        DemandCorctFanSpeed  HPTCoolantBleed  LPTCoolantBleed
# count              20631.0     20631.000000     20631.000000
# mean                 100.0        38.816271        23.289705
# std                    0.0         0.180746         0.108251
# min                  100.0        38.140000        22.894200
# 25%                  100.0        38.700000        23.221800
# 50%                  100.0        38.830000        23.297900
# 75%                  100.0        38.950000        23.366800
# max                  100.0        39.430000        23.618400
#
# [8 rows x 26 columns]

# %% [markdown]
# One cycle include segments such as start, idle, taxi, takeoff, climb, cruise, approach, landing, thrust reverse and shutdown.
#
# Find:
# - Max and min life cycles
# -
